# %%
import numpy as np
data = np.array([
    [10, -6.04417548, -9.21034037, -4.60517013, -3.21885486, -3.21885486,  
         5.99148551,   8.9996403,   7.82406698,  6.4377516,   4.60519121],
    [29, -5.9135993,  -9.21033888, -4.60516889, -3.21882891, -3.21882524,  
         5.9914983,   8.99966193,  7.82407261,  6.43780752,  4.60517351],
    [72, -5.8768937,  -9.21029984, -4.60513049, -3.21884347, -3.21883725,  
         5.99150737,  8.99961258,  7.82409166,  6.43779,     4.6052192 ],
    [164, -5.64508289, -9.21033873, -4.60516757, -3.21887573, -3.21887392,  
         5.99146579,  8.99961956,  7.82404716,  6.43775286,  4.60517028],
 ])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
f = plt.figure(figsize=(5,3))
#

cols = ['time', 'q', 'a1','a2', 'th1L', 'ph1', 'th12', 'thSL', 'thJL']
for i in range(2,10):
    #plt.plot(data[:,0], data[:, i])
    plt.plot(data[:,0], data[:, i]-data[0,i], '-o', label=cols[i-1])
plt.xlabel("Number of training points")
plt.ylabel(r"$\Delta$ Trained Scale length")
plt.xlim([0, 240])
plt.legend(loc="right")
plt.savefig("convergence.png")
