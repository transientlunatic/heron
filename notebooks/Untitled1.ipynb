# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.xkcd()

# %%
import numpy as np

# %%
lasers = np.linspace(0,100)
coolness = np.log(lasers)
# Out:
# /home/daniel/.virtualenvs/heron/lib/python2.7/site-packages/ipykernel/__main__.py:2: RuntimeWarning: divide by zero encountered in log
#   from ipykernel import kernelapp as app

# %%
plt.figure(figsize=(15,12))
plt.plot(lasers,coolness)
plt.xlabel("Laseriness")
plt.ylabel("Coolness")
